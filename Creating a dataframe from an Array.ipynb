# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1 Creating Dataframe From Array
# ## 1.1 Option_1

# %%
#Creating an Array
data = np.array([[1,4], [2,5], [3,6]])

# %%
#Craeting a dataframe...
data = pd.DataFrame(data, index = ["row1", "row2", "row3"],
                    columns = ["column1", "column2"])

# %%
data
# Out:
#       column1  column2
# row1        1        4
# row2        2        5
# row3        3        6

# %% [markdown]
# ## 1.2 Option2

# %%
import pandas as pd 
import numpy as np

# %%
data = np.array([[1,2],[3,4]])

# %%
dataset = pd.DataFrame(data, index = ("row1", "row2"),
                       columns = ("column1", "column2"))

# %%
dataset
# Out:
#       column1  column2
# row1        1        2
# row2        3        4

# %% [markdown]
# # 2. Creating a Dataframe from a dictionary...

# %%
states = ["Kolkata", "Delhi", "Pune"]
population = [120000, 46772, 736454]

# %%
dictionary = {"States":states, "Populationns":population}

# %%
data = pd.DataFrame(dictionary)
data
# Out:
#     States  Populationns
# 0  Kolkata        120000
# 1    Delhi         46772
# 2     Pune        736454

# %% [markdown]
# # Creating a data frame from a  csv file

# %%
data = pd.read_csv("student-scores.csv")

# %%
data.head(10)
# Out:
#    id first_name  last_name                                  email  gender  \
# 0   1       Paul      Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle   Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina    Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara      Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony     Campos     anthony.campos.5@gslingacademy.com    male
# 5   6      Kelly       Wade         kelly.wade.6@gslingacademy.com  female
# 6   7    Anthony      Smith      anthony.smith.7@gslingacademy.com    male
# 7   8     George      Short       george.short.8@gslingacademy.com    male
# 8   9    Stanley  Gutierrez  stanley.gutierrez.9@gslingacademy.com    male
# 9  10     Audrey    Simpson    audrey.simpson.10@gslingacademy.com  female
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# ...

# %%
data.tail(11)
# Out:
#         id first_name last_name                                    email  \
# 1989  1990     Samuel     Baker      samuel.baker.1990@gslingacademy.com
# 1990  1991    Anthony     Moore     anthony.moore.1991@gslingacademy.com
# 1991  1992  Charlotte      Rowe    charlotte.rowe.1992@gslingacademy.com
# 1992  1993       John  Peterson     john.peterson.1993@gslingacademy.com
# 1993  1994      Shawn     Ochoa       shawn.ochoa.1994@gslingacademy.com
# 1994  1995     Steven     Lewis      steven.lewis.1995@gslingacademy.com
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# ...

# %%
data.shape
# Out:
# (2000, 17)

# %%
# Displaying the number of rows
pd.set_option("display.max_rows", 1000)
data
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# ...

# %% [markdown]
# # 1. Attributes

# %%
# Getting access to the shape attribute of the dataframe   
data.shape
# Out:
# (2000, 17)

# %%
# Getting access to the index attribute of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
# Get access to the columns attribute of the dataframe
data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'part_time_job',
#        'absence_days', 'extracurricular_activities', 'weekly_self_study_hours',
#        'career_aspiration', 'math_score', 'history_score', 'physics_score',
#        'chemistry_score', 'biology_score', 'english_score', 'geography_score'],
#       dtype='object')

# %%
# Data types of the columns in the dataframe
data.dtypes
# Out:
# id                             int64
# first_name                    object
# last_name                     object
# email                         object
# gender                        object
# part_time_job                   bool
# absence_days                   int64
# extracurricular_activities      bool
# weekly_self_study_hours        int64
# career_aspiration             object
# math_score                     int64
# history_score                  int64
# physics_score                  int64
# chemistry_score                int64
# biology_score                  int64
# english_score                  int64
# geography_score                int64
# dtype: object

# %% [markdown]
# # 2. Methods

# %%
# Showing the first 5 columns of the dataframe
data.columns[:5]
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender'], dtype='object')

# %%
# Showing the info of the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          2000 non-null   int64
#  1   first_name                  2000 non-null   object
#  2   last_name                   2000 non-null   object
#  3   email                       2000 non-null   object
#  4   gender                      2000 non-null   object
#  5   part_time_job               2000 non-null   bool
#  6   absence_days                2000 non-null   int64
#  7   extracurricular_activities  2000 non-null   bool
#  8   weekly_self_study_hours     2000 non-null   int64
#  9   career_aspiration           2000 non-null   object
#  10  math_score                  2000 non-null   int64
#  11  history_score               2000 non-null   int64
#  12  physics_score               2000 non-null   int64
# ...

# %%
# Describing basic statistical details of the dataframe
data.describe()
# Out:
#                 id  absence_days  weekly_self_study_hours   math_score  \
# count  2000.000000   2000.000000              2000.000000  2000.000000
# mean   1000.500000      3.665500                17.755500    83.452000
# std     577.494589      2.629271                12.129604    13.224906
# min       1.000000      0.000000                 0.000000    40.000000
# 25%     500.750000      2.000000                 5.000000    77.000000
# 50%    1000.500000      3.000000                18.000000    87.000000
# 75%    1500.250000      5.000000                28.000000    93.000000
# max    2000.000000     10.000000                50.000000   100.000000
#
#        history_score  physics_score  chemistry_score  biology_score  \
# count    2000.000000    2000.000000      2000.000000     2000.00000
# mean       80.332000      81.336500        79.995000       79.58150
# std        12.736046      12.539453        12.777895       13.72219
# ...

# %% [markdown]
# # 3. Functions

# %%
# obtain the length of the dataframe
len(data)
# Out:
# 2000

# %%
# Obtaining the highest index value of the dataframe
max(data)
# Out:
# 'weekly_self_study_hours'

# %%
# Obtaining the highest index value of the dataframe
data.index.max()
# Out:
# 1999

# %%
# Obtaining the lowest index value of the dataframe
data.index.min()
# Out:
# 0

# %%
# Obtain the data types
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 1 Selecting one column
#
# ## 1.1 Syntax_1

# %%
data["email"]
# Out:
# 0                paul.casey.1@gslingacademy.com
# 1         danielle.sandoval.2@gslingacademy.com
# 2              tina.andrews.3@gslingacademy.com
# 3                tara.clark.4@gslingacademy.com
# 4            anthony.campos.5@gslingacademy.com
#                          ...
# 1995       alan.reynolds.1996@gslingacademy.com
# 1996      thomas.gilbert.1997@gslingacademy.com
# 1997       madison.cross.1998@gslingacademy.com
# 1998    brittany.compton.1999@gslingacademy.com
# 1999       natalie.smith.2000@gslingacademy.com
# Name: email, Length: 2000, dtype: object

# %%
# Select two or more columns of the dataframe
data[["email", "gender", "math_score"]]
# Out:
#                                         email  gender  math_score
# 0              paul.casey.1@gslingacademy.com    male          73
# 1       danielle.sandoval.2@gslingacademy.com  female          90
# 2            tina.andrews.3@gslingacademy.com  female          81
# 3              tara.clark.4@gslingacademy.com  female          71
# 4          anthony.campos.5@gslingacademy.com    male          84
# ...                                       ...     ...         ...
# 1995     alan.reynolds.1996@gslingacademy.com    male          83
# 1996    thomas.gilbert.1997@gslingacademy.com    male          89
# 1997     madison.cross.1998@gslingacademy.com  female          97
# 1998  brittany.compton.1999@gslingacademy.com  female          51
# 1999     natalie.smith.2000@gslingacademy.com  female          82
#
# [2000 rows x 3 columns]

# %% [markdown]
# # 1. Adding a new column...
#
# ## 1.1/ Adding a new column with a scalar value...

# %%
data["language_score"] = 70
data
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# ...

# %% [markdown]
# ## 1.2 Adding a new column with an array

# %%
# creating a random int between 40 and 100
data["language_score"] = np.random.randint(40, 80, size = len(data))
data
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# ...

# %% [markdown]
# ## 1.2 Insert()
# ### insert  a column at a specific position or index...

# %%
data.insert(1, "test_score", np.random.randint(40, 80, size = len(data)))

# %%
data
# Out:
#         id  test_score first_name last_name  \
# 0        1          48       Paul     Casey
# 1        2          65   Danielle  Sandoval
# 2        3          61       Tina   Andrews
# 3        4          66       Tara     Clark
# 4        5          57    Anthony    Campos
# ...    ...         ...        ...       ...
# 1995  1996          64       Alan  Reynolds
# 1996  1997          67     Thomas   Gilbert
# 1997  1998          75    Madison     Cross
# 1998  1999          53   Brittany   Compton
# 1999  2000          44    Natalie     Smith
#
#                                         email  gender  part_time_job  \
# 0              paul.casey.1@gslingacademy.com    male          False
# 1       danielle.sandoval.2@gslingacademy.com  female          False
# 2            tina.andrews.3@gslingacademy.com  female          False
# 3              tara.clark.4@gslingacademy.com  female          False
# 4          anthony.campos.5@gslingacademy.com    male          False
# ...

# %% [markdown]
# # 1. Math_Operations...
#
# ### 1.1/ Operations in column...

# %%
data["math_score"].sum()
# Out:
# np.int64(166904)

# %%
data["math_score"].count()
# Out:
# np.int64(2000)

# %%
data["math_score"].mean()
# Out:
# np.float64(83.452)

# %%
data["math_score"].max()
# Out:
# 100

# %%
data["math_score"].min()
# Out:
# 40

# %% [markdown]
# ### 1.2 Operation in Rows...

# %%
data["physics_score"] + data["math_score"] + data["language_score"]
# Out:
# 0       241
# 1       259
# 2       241
# 3       220
# 4       228
#        ...
# 1995    229
# 1996    222
# 1997    232
# 1998    197
# 1999    215
# Length: 2000, dtype: int64

# %%
x = (data["physics_score"] + data["math_score"] + data["language_score"]).mean()

# %%
x.round(1)
# Out:
# np.float64(224.2)
